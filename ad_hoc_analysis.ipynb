# %%
import pandas as pd

csv_path = "resultados/robbustness_experiment_results.csv"
df = pd.read_csv(csv_path)
df
# Out:
#      N  M  GC_LOWER_BOUND  GC_UPPER_BOUND  GC_LOWER_BOUND_REQUIRED_ITERATIONS  \
# 0    1  1        0.101520        0.123364                                 7.0
# 1    1  1        0.101520        0.123364                                 7.0
# 2    1  1        0.101520        0.123364                                 7.0
# 3    1  1        0.101520        0.123364                                 7.0
# 4    1  1        0.101520        0.123364                                 7.0
# ..  .. ..             ...             ...                                 ...
# 160  4  2        0.546623        0.621961                               578.0
# 161  4  2        0.546623        0.621961                               578.0
# 162  4  2        0.546623        0.621961                               578.0
# 163  4  2        0.546623        0.621961                               578.0
# 164  4  2        0.546623        0.621961                               578.0
#
# ...

# %%
df.loc[144, :]
# Out:
# N                                          1.000000
# M                                          4.000000
# GC_LOWER_BOUND                        145007.000000
# GC_UPPER_BOUND                       -145007.000000
# GC_LOWER_BOUND_REQUIRED_ITERATIONS         5.000000
# GC_UPPER_BOUND_REQUIRED_ITERATIONS         9.000000
# GC_SECONDS_TAKEN                           0.460634
# LP_LOWER_BOUND                                  NaN
# LP_UPPER_BOUND                                  NaN
# LP_SECONDS_TAKEN                                NaN
# TRUE_VALUE                                 0.119059
# Name: 144, dtype: float64

# %%
df.loc[145, :]
# Out:
# N                                          1.000000
# M                                          4.000000
# GC_LOWER_BOUND                        145007.000000
# GC_UPPER_BOUND                       -145007.000000
# GC_LOWER_BOUND_REQUIRED_ITERATIONS         5.000000
# GC_UPPER_BOUND_REQUIRED_ITERATIONS         9.000000
# GC_SECONDS_TAKEN                           0.459509
# LP_LOWER_BOUND                                  NaN
# LP_UPPER_BOUND                                  NaN
# LP_SECONDS_TAKEN                                NaN
# TRUE_VALUE                                 0.119059
# Name: 145, dtype: float64
